# %% [markdown]
# # 14 - Run Training Pipeline

# %% [markdown]
# This notebook runs the full training pipeline by executing key preprocessing, simulation, encoding, splitting, and model evaluation steps from other notebooks. It's the central workflow to produce and review model-ready data.

# %%
# %run 02_data_cleaning.ipynb
# %run 03_simulate_additional_information.ipynb
# %run 04_encode_data.ipynb
# %run 05_train_test_split.ipynb
# %run 10_counterfactual_calculation.ipynb
# %run 11_create_static_data_for_mvp.ipynb

# %run 14_review_predictions.ipynb
# Out:
# tbl_action_df:
#    ActID  ActionID  EmpID  EffectiveDt
# 0      1        10      1  01/Jan/2015
# 1      2        10      2  01/Jan/2015
# 2      3        10      3  06/Oct/2015
# 3      4        10      4  01/Jan/2015
# 4      5        10      5  22/May/2015
# tbl_employee_df:
#    EmpID              EmpName       EngDt       TermDt  DepID  GenderID  \
# 0      1          Nash, Kay K  01/01/2015  29/May/2017      8         1
# 1      2   Simpson, Raymond X  01/01/2015          NaN      7         0
# 2      3        Devlin, Kay M  06/10/2015  24/Jun/2019     10         1
# 3      4  Massie, Elisabeth V  01/01/2015          NaN      4         1
# 4      5    Mead, Catherine N  22/05/2015  15/Jul/2020      8         1
#
#    RaceID  MgrID          DOB  PayRate  Level
# 0       1      1  12/Feb/1987      NaN      1
# 1       4      2  15/Nov/1982      NaN      1
# 2       5      3  22/Feb/1986      NaN      1
# 3       2      4  25/May/1977      NaN      1
# ...
